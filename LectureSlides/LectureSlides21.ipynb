# %% [markdown]
# # PHYS 210 Day 21 - Nov 24, 2025
# Agenda:
#
# 1. Announcements
# 1. Reading recap, polling questions and Q&A
# 1. Group Worksheet

# %% [markdown]
# ## Poster presentations next week
# Posters do not need to be on "accepted for publication" projects. Just share your favourite project.
# * **By Wednesday:** Complete the Poster presentation sign-up survey + sign up using the course calendar
# * **Before Monday (ideally this Wednesday):** Test connecting your computer to one of these TVs

# %% [markdown]
# # Reading recap

# %% [markdown]
# ### Regular vs structured arrays
# Regular numpy arrays
# * All the same type of data
# * 2D arrays use our regular array indexing: `arr[1,2]`

# %% [markdown]
# Array indexing examples

# %%
import numpy as np
arr = np.array([[1,2],[3,4],[5,6]])
print("arr type:",type(arr))
print(arr)
print("arr[1,0]:",arr[1,0])
# Out:
# arr type: <class 'numpy.ndarray'>
# [[1 2]
#  [3 4]
#  [5 6]]
# arr[1,0]: 3

# %%
print(arr[1])
# Out:
# [3 4]

# %%
print(arr[1][0])

# %% [markdown]
# ### Regular vs structured arrays
# Structured arrays
# * Can have multiple data types in same array
# * Named fields/columns
# * Can access data by field names

# %% [markdown]
# Let's make a structured array

# %%
sarr = np.array([(1, 2.54, 'Britsh Columbia'), (3, 4.51, 'Alberta'), (5, 6.75, 'Saskatchewan')],
                dtype=[('ID', 'i4'), ('Score', 'f4'), ('Province', 'U20')])

# %% [markdown]
# Notice that the rows are now represented as tuples

# %%
print(sarr)
print("sarr.dtype.names:",sarr.dtype.names)
# Out:
# [(1, 2.54, 'Britsh Columbia') (3, 4.51, 'Alberta')
#  (5, 6.75, 'Saskatchewan')]
# sarr.dtype.names: ('ID', 'Score', 'Province')

# %%
# Our regular array indexing no longer works
print(sarr[0,1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-09eef0fa6abf> in <module>
#       1 # Our regular array indexing no longer works
# ----> 2 print(sarr[0,1])
#
# IndexError: too many indices for array

# %%
print("sarr['Province']:", sarr['Province'])
# Out:
# sarr['Province']: ['Britsh Columbia' 'Alberta' 'Saskatchewan']

# %%
print("sarr[0]:",sarr[0])
# Out:
# sarr[0]: (1, 2.54, 'Britsh Columbia')

# %%
print("sarr[0]['Province']:",sarr[0]['Province'])
# Out:
# sarr[0]['Province']: Britsh Columbia

# %%
print("sarr['Province'][0]:",sarr['Province'][0])
# Out:
# sarr['Province'][0]: Britsh Columbia

# %%
sarr[0][2]
# Out:
# 'Britsh Columbia'

# %%
sarr[0,2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-3ac66e85b510> in <module>
# ----> 1 sarr[0,2]
#
# IndexError: too many indices for array

# %%
col0_data = sarr[sarr.dtype.names[2]]
print(col0_data)
# Out:
# ['Britsh Columbia' 'Alberta' 'Saskatchewan']

# %% [markdown]
# ## Group worksheet time
